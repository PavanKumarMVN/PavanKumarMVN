# %%
print('M.V.N Pavan Kumar')
# Out:
# M.V.N Pavan Kumar

# %%
fav_food="Chicken"

# %%
print(fav_food)
# Out:
# Chicken

# %%
place="Markapur"

# %%
print(place)
# Out:
# Markapur

# %%
print(place.upper())
# Out:
# MARKAPUR

# %%
print(place.lower())
# Out:
# markapur

# %%
print(place.title())
# Out:
# Markapur

# %%
fav_hero="Pawan Kalyan"

# %%
movie_title="Bheemla Nayak"

# %%
example=f"{fav_hero} next movie is {movie_title}"

# %%
print(example)
# Out:
# Pawan Kalyan next movie is Bheemla Nayak

# %%
print(example.upper())
# Out:
# PAWAN KALYAN NEXT MOVIE IS BHEEMLA NAYAK

# %%
## Adding of white spaces

# %%
print("\tpavan kumar")
# Out:
# 	pavan kumar

# %%
print("Actors:\n\tPawan Kalyan\n\tMahesh Babu\n\tNTR\n\tPrabhas\n\tAllu Arjun")
# Out:
# Actors:
# 	Pawan Kalyan
# 	Mahesh Babu
# 	NTR
# 	Prabhas
# 	Allu Arjun

# %%
fav_lang="        Python"

# %%
print(fav_lang)
# Out:
#         Python

# %%
print(fav_lang.lstrip())
# Out:
# Python

# %%
print(fav_lang.rstrip())
# Out:
#         Python

# %%
a=1
b=2
c=a+b

# %%
6+5
# Out:
# 11

# %%
5-6
# Out:
# -1

# %%
d=6513
f=231568

# %%
d+f
# Out:
# 238081

# %%
546847416*1573
# Out:
# 860190985368

# %%
315**21
# Out:
# 29142152705945983961978464518045840484142303466796875

# %%
m=5453*82

# %%
print(m)
# Out:
# 447146

# %%
type(m)
# Out:
# int

# %%
m,v,n=3,7,9

# %%
print(m,v,n)
# Out:
# 3 7 9

# %%
chocolates=['dairy milk','5 star','kit kat','bourbon']

# %%
print(chocolates)
# Out:
# ['dairy milk', '5 star', 'kit kat', 'bourbon']

# %%
type(chocolates)
# Out:
# list

# %%
print(chocolates[3])
# Out:
# bourbon

# %%
print(chocolates[0])
# Out:
# dairy milk

# %%
print(chocolates[5])
# Out:
# kit kat

# %%
chocolates.append('Asha')

# %%
print(chocolates)
# Out:
# ['dairy milk', '5 star', 'kit kat', 'bourbon', 'Asha']

# %%
chocolates.insert(0,'Strawberry')

# %%
print(chocolates)
# Out:
# ['Strawberry', 'dairy milk', '5 star', 'kit kat', 'bourbon', 'Asha']

# %%
## Adding of elements in dict

# %%
p={'Name':'Pavan','Branch':'ECE','Roll no:':'17351A0473','Native':'Markapur'}

# %%
print(p)
# Out:
# {'Name': 'Pavan', 'Branch': 'ECE', 'Roll no:': '17351A0473', 'Native': 'Markapur'}

# %%
p['college']='SGIT'

# %%
print(p)
# Out:
# {'Name': 'Pavan', 'Branch': 'ECE', 'Roll no:': '17351A0473', 'Native': 'Markapur', 'college': 'SGIT'}

# %%
p['Pin Code']=523315

# %%
print(p)
# Out:
# {'Name': 'Pavan', 'Branch': 'ECE', 'Roll no:': '17351A0473', 'Native': 'Markapur', 'college': 'SGIT', 'Pin Code': 523315}

# %%
## Updating of elements in dict

# %%
p['Pin Code']=523316

# %%
print(p)
# Out:
# {'Name': 'Pavan', 'Branch': 'ECE', 'Roll no:': '17351A0473', 'Native': 'Markapur', 'college': 'SGIT', 'Pin Code': 523316}

# %%
p['Name']='M.V.N Pavan Kumar'

# %%
print(p)
# Out:
# {'Name': 'M.V.N Pavan Kumar', 'Branch': 'ECE', 'Roll no:': '17351A0473', 'Native': 'Markapur', 'college': 'SGIT', 'Pin Code': 523316}

# %%
p['Name']
# Out:
# 'M.V.N Pavan Kumar'

# %%
p['Pin Code']
# Out:
# 523316

# %%
p['Native']
# Out:
# 'Markapur'

# %%
p['college']
# Out:
# 'SGIT'

# %%
del p

# %%
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c7efc66e9b10> in <module>
# ----> 1 print(p)
#
# NameError: name 'p' is not defined

# %%
v={'Name':'hyd','Lan':'Telugu','Famous':'Charminar'}

# %%
print(v)
# Out:
# {'Name': 'hyd', 'Lan': 'Telugu', 'Famous': 'Charminar'}

# %%
h=v

# %%
print(h)
# Out:
# {'Name': 'hyd', 'Lan': 'Telugu', 'Famous': 'Charminar'}

# %%
del v

# %%
print(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-d6c1535c9ec8> in <module>
# ----> 1 print(v)
#
# NameError: name 'v' is not defined

# %%
h
# Out:
# {'Name': 'hyd', 'Lan': 'Telugu', 'Famous': 'Charminar'}

# %%
h.clear()

# %%
print(h)
# Out:
# {}

# %%
del h

# %%
print(h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-569b33bf2f3f> in <module>
# ----> 1 print(h)
#
# NameError: name 'h' is not defined

# %%
a={56.56,21465.2156,15,56,1565,18651,16541,168256,687135,21}

# %%
print(a)
# Out:
# {168256, 15, 21, 16541, 56.56, 21465.2156, 56, 18651, 1565, 687135}

# %%
type(a)
# Out:
# set

# %%
b={9,9,9,9,9,9,53,516,315043,54351,0,0,0,0,0,0,0,0}

# %%
print(b)
# Out:
# {0, 315043, 516, 9, 54351, 53}

# %%
type(b)
# Out:
# set

# %%
x={135,5463141,16765,416387,'Python',302,2342635,303,43.31}

# %%
print(x)
# Out:
# {416387, 5463141, 135, 2342635, 43.31, 302, 303, 'Python', 16765}

# %%
len(x)
# Out:
# 9

# %%
## Adding

# %%
x.add(473)

# %%
print(x)
# Out:
# {416387, 5463141, 135, 2342635, 43.31, 302, 303, 473, 'Python', 16765}

# %%
x.add('Language')

# %%
print(x)
# Out:
# {416387, 5463141, 135, 'Language', 2342635, 43.31, 302, 303, 473, 'Python', 16765}

# %%
## Updating

# %%
l={23,2354,5463}

# %%
print(l)
# Out:
# {416387, 5463141, 135, 'Language', 2342635, 43.31, 302, 303, 2354, 23, 5463, 473, 'Python', 16765}

# %%
print(x)
# Out:
# {416387, 5463141, 135, 'Language', 2342635, 43.31, 302, 303, 473, 'Python', 16765}

# %%
l.update(x)

# %%
print(l)
# Out:
# {416387, 5463141, 135, 'Language', 2342635, 43.31, 302, 303, 2354, 23, 5463, 473, 'Python', 16765}

# %%
## deleting

# %%
l.remove('Python')

# %%
print(l)
# Out:
# {416387, 5463141, 135, 'Language', 2342635, 43.31, 302, 303, 2354, 23, 5463, 473, 16765}

# %%
x.remove('Language')

# %%
print(x)
# Out:
# {416387, 5463141, 135, 2342635, 43.31, 302, 303, 473, 'Python', 16765}

# %%
len(x)
# Out:
# 10

# %%
len(l)
# Out:
# 13

# %%
case study:

# %%
sms=input('pls say something')
# Out:
# pls say something How are you

# %%
type(sms)
# Out:
# str

# %%
num=input('pls enter a number:')
# Out:
# pls enter a number: 4642473

# %%
type(num)
# Out:
# str

# %%
age=input('How old are you:')
if int(age)>=18:
    print('you are eligible to vote')
else:
    print('sry you are not eligible to vote')
# Out:
# How old are you:25
# you are eligible to vote

# %%
age=input('How old are you:')
if int(age)>=18:
    print('you are eligible to vote')
else:
    print('sry you are not eligible to vote')
# Out:
# How old are you:10
# sry you are not eligible to vote

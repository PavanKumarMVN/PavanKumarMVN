# %% [markdown]
# ## File Handling

# %%
## requesting and reading a text file

# %%
with open("demo.txt") as file_object:
    contents=file_object.read()
print(contents)
# Out:
# Manepalli Venkata Nagendra Pavan Kumar
# 17351A0473
# Electronics and Communication Enginnering
# Dr. Samuel George Institute of Engineering and Technology
# Markapur (523316)
# Prakasam district
# Andhra Pradesh
# India
# Asia
# Earth
# Solar System
# Milkyway Galaxy

# %%
## another syntax

# %%
s=open("demo.txt","r")
print(s.read())
# Out:
# Manepalli Venkata Nagendra Pavan Kumar
# 17351A0473
# Electronics and Communication Enginnering
# Dr. Samuel George Institute of Engineering and Technology
# Markapur (523316)
# Prakasam district
# Andhra Pradesh
# India
# Asia
# Earth
# Solar System
# Milkyway Galaxy

# %%
s=open("demo.txt","r")
print(s.read(30))
# Out:
# Manepalli Venkata Nagendra Pav

# %%
s=open("demo.txt","r")
print(s.read(29))
# Out:
# Manepalli Venkata Nagendra Pa

# %%
## Write Operation

# %%
print(s.read())
# Out:
# van Kumar
# 17351A0473
# Electronics and Communication Enginnering
# Dr. Samuel George Institute of Engineering and Technology
# Markapur (523316)
# Prakasam district
# Andhra Pradesh
# India
# Asia
# Earth
# Solar System
# Milkyway Galaxy

# %%
filename="demo.txt"
with open(filename,"w") as file_object:
    file_object.write("these are my details")
    
with open("demo.txt") as file_object:
    contents=file_object.read()
    print(contents)
# Out:
# these are my details

# %%
filename="demo.txt"
with open(filename,"w") as file_object:
    file_object.write("My Details")
    
with open("demo.txt") as file_object:
    contents=file_object.read()
    print(contents)
# Out:
# My Details

# %%
## Append

# %%
filename="demo.txt"
with open(filename,"a") as file_object:
    file_object.write(", Which tells about me")
    
with open("demo.txt") as file_object:
    contents=file_object.read()
    print(contents)
# Out:
# My Details ,Which tells about me, Which tells about me

# %% [markdown]
# ## Exceptional Handling

# %%
1. Zero Division Error

# %%
5/5
# Out:
# 1.0

# %%
0/5
# Out:
# 0.0

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-21-0106664d39e8> in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
36546831/36546830
# Out:
# 1.0000000273621543

# %%
try:
    print(365265/0)
except:
    print("Pls dont try to divide by zero")
# Out:
# Pls dont try to divide by zero

# %%
try:
    print(365265/5230)
except:
    print("Pls dont try to divide by zero")
# Out:
# 69.84034416826003

# %%
a=5
b=35

try:
    print(a/b)
except:
    print("It is not possible")
# Out:
# 0.14285714285714285

# %%
a=5
b=00

try:
    print(a/b)
except:
    print("It is not possible")
# Out:
# It is not possible

# %%
2. Filenot found error

# %%
filename="demo.txt"
with open("demo.txt") as file_object:
    contents=file_object.read()
    print(contents)
# Out:
# My Details Details

# %%
filename="pavan.txt"
with open("pavan.txt") as file_object:
    contents=file_object.read()
    print(contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-6f93b3857277> in <module>
#       1 filename="pavan.txt"
# ----> 2 with open("pavan.txt") as file_object:
#       3     contents=file_object.read()
#       4     print(contents)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pavan.txt'

# %%
try:
    with open("pavan.txt") as file_object:
        contents=file_object.read()
        print(contents)
except:
    print("The given file is not there")
# Out:
# The given file is not there

# %%
try:
    with open("demo.txt") as file_object:
        contents=file_object.read()
        print(contents)
except:
    print("The given file is not there")
# Out:
# My Details Details

# %% [markdown]
# ## Splitting, Evaluation, Filtering,Lambda,Map

# %%
## 1. Eval

# %%
num=input("Enter a number: ")
# Out:
# Enter a number: 66

# %%
type(num)
# Out:
# str

# %%
num=eval(input("Enter a number: "))
# Out:
# Enter a number: 69

# %%
type(num)
# Out:
# int

# %%
## 2. Splitting

# %%
text="Hi!, how are you"

# %%
m=text.split()

# %%
print(m)
# Out:
# ['Hi!,', 'how', 'are', 'you']

# %%
type(m)
# Out:
# list

# %%
m=text.split('how')

# %%
print(m)
# Out:
# ['Hi!, ', ' are you']

# %%
## 3. lambda ----->for short operations

# %%
s=lambda a,b,c:a+b+c

# %%
print(s(1,23,3))
# Out:
# 27

# %%
def square(x):
    return x*x
sqr=lambda x:x*x
print("Square of number is:",square(53))
# Out:
# Square of number is: 2809

# %%
sqr=lambda x:x*x
print(sqr(10))
# Out:
# 100

# %%
## 4. Filtering

# %%
L1=[32,23541,69861,31469,9543512,3532543,2222343,22,2222,2222,2222,221]

# %%
even=filter(lambda n:n%2==0,L1)

# %%
even

# %%
even=list(filter(lambda n:n%2==0,L1))

# %%
even
# Out:
# [32, 9543512, 22, 2222, 2222, 2222]

# %%
## without lambda

# %%
def even(n):
    return n%2==0

# %%
Even=filter(even,L1)

# %%
even
# Out:
# <function __main__.even(n)>

# %%
Even=list(filter(even,L1))

# %%
Even
# Out:
# [32, 9543512, 22, 2222, 2222, 2222]

# %%
odd=list(filter(lambda n:n%2!=0,L1))

# %%
odd
# Out:
# [23541, 69861, 31469, 3532543, 2222343, 221]

# %%
def odd(n):
    return n%2!=0

# %%
Odd=filter(odd,L1)

# %%
Odd

# %%
Odd=list(filter(odd,L1))

# %%
Odd
# Out:
# [23541, 69861, 31469, 3532543, 2222343, 221]

# %%
## 5. Map

# %%
data=input().split(' ')
# Out:
# 51,815

# %%
L4=map(int,input().split(' '))
# Out:
# 5,681,871

# %%
L4

# %%
L4=list(map(int,input().split(' ')))
# Out:
# 651,514,514,58
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-54df7aa0106c> in <module>
# ----> 1 L4=list(map(int,input().split(' ')))
#
# ValueError: invalid literal for int() with base 10: '651,514,514,58'

# %%
L4

# %%
L5=[35,864,686,8151,31,5,0,5]

# %%
def incr(n):
    return n+2

# %%
x=list(map(incr,L5))

# %%
x
# Out:
# [37, 866, 688, 8153, 33, 7, 2, 7]

# %%
with lambda

# %%
x=list(map(lambda a:a+2,L5))

# %%
x
# Out:
# [37, 866, 688, 8153, 33, 7, 2, 7]

# %%
Phrase="giraffe academy"

# %%
Phrase.isupper()
# Out:
# False

# %%
Phrase.islower()
# Out:
# True

# %%
Trueword="TRUE"

# %%
Trueword.isupper()
# Out:
# True

# %%
name="PaVan KUmAr"

# %%
print(name.replace("KUmAr","NaVaP"))
# Out:
# PaVan NaVaP

# %%
## Swapcase

# %%
print(name)
# Out:
# PaVan KUmAr

# %%
name.swapcase()
# Out:
# 'pAvAN kuMaR'
